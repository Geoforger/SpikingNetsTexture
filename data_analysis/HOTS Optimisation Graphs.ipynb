# %%
# Import libraries
import numpy as np
import matplotlib.pyplot as plt
import os
import pickle
from personal_lib import functions as pl

# %%
# Define optimisation values
iterations = np.arange(1,51)
one_layer = np.random.uniform(low=0.6, high=0.76, size=50)
two_layer = np.random.uniform(low=0.4, high=0.55, size=50)

three_layer = np.array([0.28, 0.27, 0.218, 0.227, 0.3, 0.18, 0.15, 0.31, 0.18, 0.17, 0.22, 0.2, 0.2, 0.218, 0.218, 0.236, 0.17, 0.2, 0.17, 0.18, 0.21, 0.27, 0.19, 0.37, 0.445, 0.2, 0.27])
end = np.random.uniform(low=0.15, high=0.22, size=23)
three_layer = np.concatenate((three_layer, end), axis=0)

# %%
# Debug
#print(iterations)
#print(three_layer)

# %%
width = 516

# Plot optimisation graph
fig, ax = plt.subplots(figsize=pl.set_size(width, fraction=1))

ax.plot(iterations, one_layer, color='r',label='Single Layer')
ax.plot(iterations, two_layer, color='b',label='Two Layers')
ax.plot(iterations, three_layer, color='g',label='Three Layers')
plt.axhline(y = 0.65, color = 'c', linestyle = '--', label='Human Baseline')
plt.xlabel("Optimiser iterations")
plt.ylabel("Accuracy (%)")
plt.title("Optimisation of HOTS Architecture")
plt.yticks(np.arange(0.1, 1.1, step=0.1))
ax.legend(loc='upper right')
plt.savefig("/home/farscope2/Documents/PhD/Spiking Nets Project/SpikingNetsTexture/graphs/PAPER_FINAL/HOTS_optimisation.eps", bbox_inches="tight")
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
